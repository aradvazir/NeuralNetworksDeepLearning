# %% [markdown]
# ## Importing essential libraries

# %%
import os
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from keras.initializers import glorot_uniform
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dense, Input
from keras.optimizers import Adam

# %% [markdown]
# ## Loading the data set

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
folder_path = '/content/drive/My Drive/Alzheimer_s_Disease_Neuroimaging_ADNI_Dataset'

# %% [markdown]
# ## Preproccesing and augmentation

# %%
image_dir = folder_path

labels = ["MCI", "AD"]

image_size = (128, 128)

rescale = 1./255

augmentation_params = dict(horizontal_flip=True, shear_range=0.2, height_shift_range=0.1, rotation_range=45, zoom_range=[0.9, 1.1])

images = []
image_labels = []

datagen = ImageDataGenerator(**augmentation_params)

first_image = True

for label in labels:

    for filename in os.listdir(os.path.join(image_dir, label)):

        img = cv2.imread(os.path.join(image_dir, label, filename), cv2.IMREAD_GRAYSCALE)

        img = cv2.resize(img, image_size)

        img = img * rescale

        img_4d = img.reshape((1,) + img.shape + (1,))

        i = 0
        for batch in datagen.flow(img_4d, batch_size=1):

            images.append(batch[0])
            image_labels.append(label)
            i += 1
            if i >= 5:
                break

        if first_image:
            plt.figure(figsize=(20, 10))
            plt.subplot(1, 5, 1)
            plt.imshow(img, cmap='gray')
            plt.title('Original Image')
            for j in range(4):
                plt.subplot(1, 5, j+2)
                plt.imshow(images[j].reshape(image_size), cmap='gray')
                plt.title(f'Augmented Image {j+1}')
            plt.show()
            first_image = False
    print(f"Finished processing images for label '{label}'.")
    print(f"Number of images for label '{label}': {image_labels.count(label)}")



# Convert the lists to numpy arrays
images = np.array(images)
image_labels = np.array(image_labels)

print(f"There are {len(images)} images in the 'images' variable.")

# Convert labels to integers then one-hot encode
encoder = LabelEncoder()
image_labels_encoded = encoder.fit_transform(image_labels)
image_labels_categorical = to_categorical(image_labels_encoded)

print(f"There are {len(image_labels)} image labels in the 'image_labels' variable.")

# Now, print the unique labels and their counts
unique_labels, counts = np.unique(image_labels_encoded, return_counts=True)
print(f"There are {len(unique_labels)} unique labels in the 'image_labels_encoded' variable.")
print("The unique labels are:", unique_labels)
print("The counts of each label are:", counts)
# Out:
# Finished processing images for label 'MCI'.
# Number of images for label 'MCI': 3445
# Finished processing images for label 'AD'.
# Number of images for label 'AD': 4825
# There are 8270 images in the 'images' variable.
# There are 8270 image labels in the 'image_labels' variable.
# There are 2 unique labels in the 'image_labels_encoded' variable.
# The unique labels are: [0 1]
# The counts of each label are: [4825 3445]

# %% [markdown]
# ## Splitting the data
# **Split the data into training and testing sets (95% training, 5% testing)**
#
# **Further split the training data into training and validation sets (90% training, 10% validation)**

# %%
X_train, X_test, y_train, y_test = train_test_split(images, image_labels_categorical, test_size=0.05, random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

# %% [markdown]
# ## Defining and compiling the proposed model, model_test1, model_test2

# %%
from keras.losses import CategoricalCrossentropy

# Define the optimizer with learning rate 0.001
optimizer = Adam(learning_rate=0.001)

# Define the Glorot uniform initializer
initializer = glorot_uniform(seed=42)

# Define the Testing model 2
model_test2 = Sequential([
    Input(shape=(128, 128, 1)),  # Adjusted input shape to match the data
    Conv2D(32, (3, 3), activation='relu', kernel_initializer=initializer),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu', kernel_initializer=initializer),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu', kernel_initializer=initializer),
    Dense(64, activation='relu', kernel_initializer=initializer),
    Dense(2, activation='softmax', kernel_initializer=initializer)  # Softmax for output layer
])

# Compile the Testing model 2
model_test2.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])  # Adjusted loss function to match the data

# %%
model_test2.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_14 (Conv2D)          (None, 126, 126, 32)      320
#
#  batch_normalization_14 (Ba  (None, 126, 126, 32)      128
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 124, 124, 32)      9248
#
#  batch_normalization_15 (Ba  (None, 124, 124, 32)      128
#  tchNormalization)
#
#  max_pooling2d_10 (MaxPooli  (None, 62, 62, 32)        0
#  ng2D)
#
#  flatten_5 (Flatten)         (None, 123008)            0
#
#  dense_12 (Dense)            (None, 128)               15745152
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dense_14 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 15763362 (60.13 MB)
# Trainable params: 15763234 (60.13 MB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##Fitting and executing the Proposed model ( batch_size = 64 )

# %%
# Fit the Proposed model
history_test2_64 = model_test2.fit(X_train, y_train, batch_size=64, validation_data=(X_val, y_val), epochs=20)
# Out:
# Epoch 1/20
# 111/111 [==============================] - 9s 58ms/step - loss: 3.2732 - accuracy: 0.5815 - val_loss: 10.3956 - val_accuracy: 0.4211
# Epoch 2/20
# 111/111 [==============================] - 7s 59ms/step - loss: 0.6730 - accuracy: 0.6744 - val_loss: 8.9827 - val_accuracy: 0.4504
# Epoch 3/20
# 111/111 [==============================] - 6s 58ms/step - loss: 0.5395 - accuracy: 0.7325 - val_loss: 14.6276 - val_accuracy: 0.4288
# Epoch 4/20
# 111/111 [==============================] - 6s 58ms/step - loss: 0.4885 - accuracy: 0.7679 - val_loss: 13.8354 - val_accuracy: 0.5127
# Epoch 5/20
# 111/111 [==============================] - 6s 58ms/step - loss: 0.4238 - accuracy: 0.8047 - val_loss: 1.5823 - val_accuracy: 0.5954
# Epoch 6/20
# 111/111 [==============================] - 6s 57ms/step - loss: 0.3264 - accuracy: 0.8617 - val_loss: 0.8384 - val_accuracy: 0.6718
# Epoch 7/20
# 111/111 [==============================] - 6s 58ms/step - loss: 0.2793 - accuracy: 0.8812 - val_loss: 0.8990 - val_accuracy: 0.6947
# Epoch 8/20
# 111/111 [==============================] - 6s 58ms/step - loss: 0.1921 - accuracy: 0.9226 - val_loss: 0.7589 - val_accuracy: 0.6972
# Epoch 9/20
# 111/111 [==============================] - 6s 57ms/step - loss: 0.1057 - accuracy: 0.9610 - val_loss: 0.8506 - val_accuracy: 0.7366
# Epoch 10/20
# 111/111 [==============================] - 6s 57ms/step - loss: 0.0487 - accuracy: 0.9873 - val_loss: 0.8582 - val_accuracy: 0.7290
# Epoch 11/20
# 111/111 [==============================] - 6s 56ms/step - loss: 0.0153 - accuracy: 0.9992 - val_loss: 0.9984 - val_accuracy: 0.7112
# Epoch 12/20
# 111/111 [==============================] - 6s 57ms/step - loss: 0.0075 - accuracy: 0.9997 - val_loss: 1.0700 - val_accuracy: 0.7316
# Epoch 13/20
# 111/111 [==============================] - 6s 57ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.1459 - val_accuracy: 0.7239
# Epoch 14/20
# 111/111 [==============================] - 6s 57ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.1537 - val_accuracy: 0.7188
# Epoch 15/20
# 111/111 [==============================] - 6s 57ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.1986 - val_accuracy: 0.7239
# Epoch 16/20
# 111/111 [==============================] - 6s 56ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.2253 - val_accuracy: 0.7201
# Epoch 17/20
# 111/111 [==============================] - 6s 57ms/step - loss: 8.0697e-04 - accuracy: 1.0000 - val_loss: 1.2459 - val_accuracy: 0.7239
# Epoch 18/20
# 111/111 [==============================] - 6s 57ms/step - loss: 6.7766e-04 - accuracy: 1.0000 - val_loss: 1.2601 - val_accuracy: 0.7201
# Epoch 19/20
# 111/111 [==============================] - 6s 57ms/step - loss: 5.6975e-04 - accuracy: 1.0000 - val_loss: 1.2769 - val_accuracy: 0.7252
# Epoch 20/20
# 111/111 [==============================] - 6s 56ms/step - loss: 4.9789e-04 - accuracy: 1.0000 - val_loss: 1.3134 - val_accuracy: 0.7265

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history_test2_64.history['accuracy'])
plt.plot(history_test2_64.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_test2_64.history['loss'])
plt.plot(history_test2_64.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##Fitting and executing the Proposed model ( batch_size = 32)

# %%
# Fit the Proposed model
history_test2_32 = model_test2.fit(X_train, y_train, batch_size=32, validation_data=(X_val, y_val), epochs=20)
# Out:
# Epoch 1/20
# 221/221 [==============================] - 7s 33ms/step - loss: 5.0938e-04 - accuracy: 1.0000 - val_loss: 1.3662 - val_accuracy: 0.7366
# Epoch 2/20
# 221/221 [==============================] - 7s 31ms/step - loss: 4.0802e-04 - accuracy: 1.0000 - val_loss: 1.3413 - val_accuracy: 0.7188
# Epoch 3/20
# 221/221 [==============================] - 7s 31ms/step - loss: 3.2460e-04 - accuracy: 1.0000 - val_loss: 1.4003 - val_accuracy: 0.7188
# Epoch 4/20
# 221/221 [==============================] - 7s 31ms/step - loss: 2.3225e-04 - accuracy: 1.0000 - val_loss: 1.4637 - val_accuracy: 0.7354
# Epoch 5/20
# 221/221 [==============================] - 7s 32ms/step - loss: 1.9486e-04 - accuracy: 1.0000 - val_loss: 1.4863 - val_accuracy: 0.7303
# Epoch 6/20
# 221/221 [==============================] - 7s 31ms/step - loss: 1.5508e-04 - accuracy: 1.0000 - val_loss: 1.5053 - val_accuracy: 0.7201
# Epoch 7/20
# 221/221 [==============================] - 7s 32ms/step - loss: 1.3340e-04 - accuracy: 1.0000 - val_loss: 1.5017 - val_accuracy: 0.7239
# Epoch 8/20
# 221/221 [==============================] - 7s 30ms/step - loss: 1.1695e-04 - accuracy: 1.0000 - val_loss: 1.5603 - val_accuracy: 0.7214
# Epoch 9/20
# 221/221 [==============================] - 7s 31ms/step - loss: 9.4427e-05 - accuracy: 1.0000 - val_loss: 1.5717 - val_accuracy: 0.7252
# Epoch 10/20
# 221/221 [==============================] - 7s 30ms/step - loss: 7.3828e-05 - accuracy: 1.0000 - val_loss: 1.5915 - val_accuracy: 0.7239
# Epoch 11/20
# 221/221 [==============================] - 7s 32ms/step - loss: 6.6810e-05 - accuracy: 1.0000 - val_loss: 1.6439 - val_accuracy: 0.7277
# Epoch 12/20
# 221/221 [==============================] - 7s 30ms/step - loss: 5.4274e-05 - accuracy: 1.0000 - val_loss: 1.6449 - val_accuracy: 0.7277
# Epoch 13/20
# 221/221 [==============================] - 7s 31ms/step - loss: 4.8483e-05 - accuracy: 1.0000 - val_loss: 1.6339 - val_accuracy: 0.7239
# Epoch 14/20
# 221/221 [==============================] - 7s 31ms/step - loss: 3.9764e-05 - accuracy: 1.0000 - val_loss: 1.6575 - val_accuracy: 0.7176
# Epoch 15/20
# 221/221 [==============================] - 7s 31ms/step - loss: 3.8032e-05 - accuracy: 1.0000 - val_loss: 1.7146 - val_accuracy: 0.7379
# Epoch 16/20
# 221/221 [==============================] - 7s 31ms/step - loss: 3.1243e-05 - accuracy: 1.0000 - val_loss: 1.7314 - val_accuracy: 0.7277
# Epoch 17/20
# 221/221 [==============================] - 7s 32ms/step - loss: 2.6154e-05 - accuracy: 1.0000 - val_loss: 1.7562 - val_accuracy: 0.7201
# Epoch 18/20
# 221/221 [==============================] - 7s 30ms/step - loss: 2.2376e-05 - accuracy: 1.0000 - val_loss: 1.7718 - val_accuracy: 0.7290
# Epoch 19/20
# 221/221 [==============================] - 7s 31ms/step - loss: 1.9736e-05 - accuracy: 1.0000 - val_loss: 1.7804 - val_accuracy: 0.7290
# Epoch 20/20
# 221/221 [==============================] - 7s 31ms/step - loss: 1.6016e-05 - accuracy: 1.0000 - val_loss: 1.7839 - val_accuracy: 0.7214

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history_test2_32.history['accuracy'])
plt.plot(history_test2_32.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_test2_32.history['loss'])
plt.plot(history_test2_32.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ROC curve

# %%
y_pred_prob = model_test2.predict(X_test)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(2):  # number of classes
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC curve
plt.figure()
plt.plot(fpr[1], tpr[1], label='ROC curve (area = %0.2f)' % roc_auc[1])
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 13/13 [==============================] - 0s 8ms/step

# %% [markdown]
# ## Analysing the model

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from keras.metrics import Precision, Recall

y_pred_prob = model_test2.predict(X_test)

y_pred_class = np.argmax(y_pred_prob, axis=1)


cm = confusion_matrix(y_test.argmax(axis=1), y_pred_class)

cr = classification_report(y_test.argmax(axis=1), y_pred_class, target_names=['AD', 'MCI'])

auc = roc_auc_score(y_test, model_test2.predict(X_test))

print("Confusion Matrix:")
print(cm)

print("Classification Report:")
print(cr)

print("AUC: ", auc)
# Out:
# 13/13 [==============================] - 0s 8ms/step
# 13/13 [==============================] - 0s 8ms/step
# Confusion Matrix:
# [[194  57]
#  [ 66  97]]
# Classification Report:
#               precision    recall  f1-score   support
#
#           AD       0.75      0.77      0.76       251
#          MCI       0.63      0.60      0.61       163
#
#     accuracy                           0.70       414
#    macro avg       0.69      0.68      0.69       414
# weighted avg       0.70      0.70      0.70       414
#
# AUC:  0.792633148388043

# %% [markdown]
# ## Adding dropout to the model and analysing it

# %%
from keras.layers import Dropout

# Define the Proposed model with dropout
model_test2_dropout = Sequential([
    Input(shape=(128, 128, 1)),
    Conv2D(32, (3, 3), activation='relu', kernel_initializer=initializer),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu', kernel_initializer=initializer),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),  # Added dropout
    Conv2D(32, (3, 3), activation='relu', kernel_initializer=initializer),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu', kernel_initializer=initializer),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),  # Added dropout
    Flatten(),
    Dense(128, activation='relu', kernel_initializer=initializer),
    Dropout(0.5),  # Added dropout
    Dense(64, activation='relu', kernel_initializer=initializer),
    Dropout(0.5),  # Added dropout
    Dense(2, activation='softmax', kernel_initializer=initializer)  # Set number of units to 2 for two classes
])

# Use the legacy Adam optimizer
model_test2_dropout.compile(optimizer=tf.keras.optimizers.legacy.Adam(), loss=CategoricalCrossentropy(), metrics=['accuracy'])

# Now you can fit the model
history_test2_dropout = model_test2_dropout.fit(X_train, y_train, batch_size=64, validation_data=(X_val, y_val), epochs=20)
# Out:
# Epoch 1/20
# 111/111 [==============================] - 12s 103ms/step - loss: 1.2465 - accuracy: 0.5628 - val_loss: 1.0037 - val_accuracy: 0.5420
# Epoch 2/20
# 111/111 [==============================] - 11s 100ms/step - loss: 0.6738 - accuracy: 0.5782 - val_loss: 3.7571 - val_accuracy: 0.4160
# Epoch 3/20
# 111/111 [==============================] - 11s 100ms/step - loss: 0.6777 - accuracy: 0.5809 - val_loss: 1.7999 - val_accuracy: 0.4949
# Epoch 4/20
# 111/111 [==============================] - 11s 98ms/step - loss: 0.6790 - accuracy: 0.5813 - val_loss: 0.6960 - val_accuracy: 0.5751
# Epoch 5/20
# 111/111 [==============================] - 11s 97ms/step - loss: 0.6793 - accuracy: 0.5822 - val_loss: 0.7304 - val_accuracy: 0.5814
# Epoch 6/20
# 111/111 [==============================] - 11s 100ms/step - loss: 0.6807 - accuracy: 0.5818 - val_loss: 0.6859 - val_accuracy: 0.5827
# Epoch 7/20
# 111/111 [==============================] - 11s 99ms/step - loss: 0.6701 - accuracy: 0.5815 - val_loss: 0.7460 - val_accuracy: 0.5814
# Epoch 8/20
# 111/111 [==============================] - 11s 98ms/step - loss: 0.6713 - accuracy: 0.5818 - val_loss: 0.6744 - val_accuracy: 0.5802
# Epoch 9/20
# 111/111 [==============================] - 11s 99ms/step - loss: 0.6769 - accuracy: 0.5819 - val_loss: 0.6655 - val_accuracy: 0.5827
# Epoch 10/20
# 111/111 [==============================] - 11s 97ms/step - loss: 0.6841 - accuracy: 0.5825 - val_loss: 0.6797 - val_accuracy: 0.5827
# Epoch 11/20
# 111/111 [==============================] - 11s 95ms/step - loss: 0.6802 - accuracy: 0.5823 - val_loss: 0.6757 - val_accuracy: 0.5903
# Epoch 12/20
# 111/111 [==============================] - 11s 96ms/step - loss: 0.6798 - accuracy: 0.5823 - val_loss: 0.6764 - val_accuracy: 0.5903
# Epoch 13/20
# 111/111 [==============================] - 11s 95ms/step - loss: 0.6801 - accuracy: 0.5825 - val_loss: 0.6806 - val_accuracy: 0.5903
# Epoch 14/20
# 111/111 [==============================] - 11s 95ms/step - loss: 0.6799 - accuracy: 0.5822 - val_loss: 0.6775 - val_accuracy: 0.5852
# Epoch 15/20
# 111/111 [==============================] - 11s 95ms/step - loss: 0.6798 - accuracy: 0.5823 - val_loss: 0.6779 - val_accuracy: 0.5840
# Epoch 16/20
# 111/111 [==============================] - 10s 95ms/step - loss: 0.6796 - accuracy: 0.5823 - val_loss: 0.6778 - val_accuracy: 0.5840
# Epoch 17/20
# 111/111 [==============================] - 10s 95ms/step - loss: 0.6797 - accuracy: 0.5822 - val_loss: 0.6793 - val_accuracy: 0.5827
# Epoch 18/20
# 111/111 [==============================] - 11s 95ms/step - loss: 0.6800 - accuracy: 0.5823 - val_loss: 0.6789 - val_accuracy: 0.5827
# Epoch 19/20
# 111/111 [==============================] - 11s 95ms/step - loss: 0.6794 - accuracy: 0.5823 - val_loss: 0.6787 - val_accuracy: 0.5840
# Epoch 20/20
# 111/111 [==============================] - 11s 95ms/step - loss: 0.6798 - accuracy: 0.5823 - val_loss: 0.6787 - val_accuracy: 0.5840

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history_test2_dropout.history['accuracy'])
plt.plot(history_test2_dropout.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_test2_dropout.history['loss'])
plt.plot(history_test2_dropout.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()
